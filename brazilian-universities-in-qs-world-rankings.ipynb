# %% [markdown]
# # Improvement of Brazilian Universities

# %% [markdown]
# Analyzing the difference of the Brazilian Universities in the QS World University Rankings between the years of 2023 and 2024

# %% [markdown]
# ## Setting up the environment

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Getting the Data

# %%
ranking_path = './dataset/2024 QS World University Rankings 1.1 (For qs.com).csv'

ranking_data = pd.read_csv(ranking_path).drop(axis=0, index=0)

# %%
ranking_data.head()
# Out:
#   2024 RANK 2023 RANK                              Institution Name  \
# 1         1         1  Massachusetts Institute of Technology (MIT)
# 2         2         2                       University of Cambridge
# 3         3         4                          University of Oxford
# 4         4         5                            Harvard University
# 5         5         3                           Stanford University
#
#   Country Code         Country SIZE FOCUS RES. AGE STATUS  ...  \
# 1           US   United States    M    CO   VH   5      B  ...
# 2           UK  United Kingdom    L    FC   VH   5      A  ...
# 3           UK  United Kingdom    L    FC   VH   5      A  ...
# 4           US   United States    L    FC   VH   5      B  ...
# 5           US   United States    L    FC   VH   5      B  ...
#
#   International Faculty Rank International Students Score  \
# 1                         56                         88.2
# ...

# %% [markdown]
# ## How is the ranking distribuited around the world?

# %%
plt.figure(figsize=(10,20))
sns.set_style('darkgrid')
sns.histplot(data=ranking_data, y='Country Code')
# Out:
# <Axes: xlabel='Count', ylabel='Country Code'>

# %% [markdown]
# It's possible to say that the top 3 countries that have more universities in the ranking are:
# 1. US
# 2. UK
# 3. CN

# %% [markdown]
# ## Analyzing Brazilian Universities
# We can see that Brazil stays between 25 and 50 universities, let's get the exact number.

# %%
br_names_ranking_data = ranking_data[(ranking_data['Country Code'] == 'BR')]
br_names_ranking_data.head()
# Out:
#     2024 RANK 2023 RANK                                   Institution Name  \
# 86        =85       115                          Universidade de São Paulo
# 220      =220      210=        Universidade Estadual de Campinas (Unicamp)
# 374      =371       333             Universidade Federal do Rio de Janeiro
# 420      =419      477=                                              UNESP
# 596      =595   601-650  Pontifícia Universidade Católica do Rio de Jan...
#
#     Country Code Country SIZE FOCUS RES. AGE STATUS  ...  \
# 86            BR  Brazil   XL    FC   VH   4      A  ...
# 220           BR  Brazil   XL    FC   VH   4      A  ...
# 374           BR  Brazil   XL    FC   VH   5      A  ...
# 420           BR  Brazil   XL    FC   VH   3      A  ...
# 596           BR  Brazil    M    CO   VH   4      B  ...
#
#     International Faculty Rank International Students Score  \
# 86                        701+                          2.3
# ...

# %%
br_names_ranking_data['Institution Name'].count()
# Out:
# 35

# %% [markdown]
# Brazil has 35 universities in the ranking.

# %% [markdown]
# ## Analyzing Brazilian Universities and their position in 2023 and 2024 rank

# %%
br_names_ranking_data[['Institution Name', '2023 RANK', '2024 RANK']]
# Out:
#                                        Institution Name  2023 RANK  2024 RANK
# 86                            Universidade de São Paulo        115        =85
# 220         Universidade Estadual de Campinas (Unicamp)       210=       =220
# 374              Universidade Federal do Rio de Janeiro        333       =371
# 420                                               UNESP       477=       =419
# 596   Pontifícia Universidade Católica do Rio de Jan...    601-650       =595
# 695          Universidade Federal de Minas Gerais          701-750    691-700
# 696          Universidade Federal do Rio Grande Do Sul     751-800    691-700
# 739                   Universidade Federal de São Paulo       441=    731-740
# 833                            Universidade de Brasília   801-1000    801-850
# 834             Universidade Federal de Santa Catarina    801-1000    801-850
# 1083      Pontifícia Universidade Católica de São Paulo   801-1000  1001-1200
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# On average, most of the universities stayed at the same position between the years of 2023 and 2024. However, we can see that on the top five, three of them (60%) could move up - Universidade de São Paulo, UNESP and Pontifícia Universidade Católica do Rio de Janeiro.
#
# Also, it's important to know that according to the [QS website](https://www.topuniversities.com) "The results draw on the analysis of 17.5m academic papers and the expert opinions of over 240,000 academic faculty and employers."
